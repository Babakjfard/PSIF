# %%
import xarray as xr
import geopandas as gpd

# %%
winds_test = xr.open_dataset('../data/winds/daily_wind_Nebraska_statistics_2023.nc')

# %%
winds_test
# Out:
# <xarray.Dataset> Size: 44MB
# Dimensions:             (lat: 40, lon: 91, time: 126)
# Coordinates:
#   * lat                 (lat) float64 320B 39.06 39.19 39.31 ... 43.81 43.94
#   * lon                 (lon) float64 728B -105.3 -105.2 ... -94.19 -94.06
#   * time                (time) datetime64[ns] 1kB 2023-01-29 ... 2023-06-03
# Data variables: (12/16)
#     avg_speed_sector_1  (time, lat, lon) float32 2MB ...
#     duration_sector_1   (time, lat, lon) float64 4MB ...
#     avg_speed_sector_2  (time, lat, lon) float32 2MB ...
#     duration_sector_2   (time, lat, lon) float64 4MB ...
#     avg_speed_sector_3  (time, lat, lon) float32 2MB ...
#     duration_sector_3   (time, lat, lon) float64 4MB ...
#     ...                  ...
#     avg_speed_sector_6  (time, lat, lon) float32 2MB ...
#     duration_sector_6   (time, lat, lon) float64 4MB ...
#     avg_speed_sector_7  (time, lat, lon) float32 2MB ...
#     duration_sector_7   (time, lat, lon) float64 4MB ...
# ...
